# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
import json

# %%
img = cv2.imread("usb_cam.png")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_crop = img[130:200, 110:570]
plt.imshow(cv2.cvtColor(img_crop, cv2.COLOR_BGR2RGB))
plt.show()
img_crop.shape
# Out:
# (70, 460, 3)

# %%
# with open("coordinates.json", "r") as f:
#     data = json.load(f)

# data_scaled = {
#     "y_min": int(data["y_min"] * 70/523),
#     "y_max": int(data["y_max"] * 70/523),
#     "x": []
# }

# for x, count in data["x"]:
#     data_scaled["x"].append([int(x * 460/3767), count])

# data_scaled

data_scaled = {
    'y_min': 9,
    'y_max': 69,
    'x': [
        [5, 1],
        [53, 3],
        [97, 4],
        [141, 3],
        [185, 2],
        [227, 1],
        [270, 2],
        [314, 2],
        [358, 3],
        [402, 2],
        [453, 1]
    ]
}

# %%
img_line = img_crop.copy()
for x, count in data_scaled["x"]:
    cv2.line(img_line, (x, data_scaled["y_min"]), (x, data_scaled["y_max"]), (255, 0, 0), 1)
plt.imshow(cv2.cvtColor(img_line, cv2.COLOR_BGR2RGB))
plt.show()

# %%
with open("coordinates_scaled.json", "w") as f:
    json.dump(data_scaled, f)
